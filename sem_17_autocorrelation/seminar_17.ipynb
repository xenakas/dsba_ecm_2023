# %%
library(hexView)

data <- readEViews('EXPEND.WF1')
# Out:
# Warning message in readEViews("EXPEND.WF1"):
# “Skipping boilerplate variable
# ”
# Warning message in readEViews("EXPEND.WF1"):
# “Skipping boilerplate variable
# ”

# %%
data
# Out:
#    Date       AIR CLOT COSM DATE DENT DOC  DPI    FOOD  FUEL ⋯ PTOB  PTPE
# 1  1959-01-01 0.9 36.3 3.1  1959 3.2   8.8  479.7  99.7 5.2  ⋯  61.0  70.6
# 2  1960-01-01 0.9 36.6 3.5  1960 3.2   9.0  489.7 100.9 5.0  ⋯  63.2  71.9
# 3  1961-01-01 1.0 37.3 3.9  1961 3.3   9.1  503.8 102.5 4.7  ⋯  63.8  72.6
# 4  1962-01-01 1.1 38.9 4.2  1962 3.5   9.8  524.9 103.5 4.7  ⋯  64.4  73.7
# 5  1963-01-01 1.2 39.6 4.5  1963 3.4  10.2  542.3 104.6 4.9  ⋯  65.8  74.8
# 6  1964-01-01 1.4 42.6 4.8  1964 3.9  11.9  580.8 108.8 5.2  ⋯  67.1  75.9
# 7  1965-01-01 1.6 44.2 5.3  1965 4.0  12.1  616.3 113.7 5.5  ⋯  69.8  77.2
# 8  1966-01-01 1.7 46.9 5.9  1966 4.1  12.1  646.8 116.6 5.6  ⋯  72.9  79.4
# 9  1967-01-01 2.1 46.9 6.3  1967 4.3  12.5  673.5 118.6 5.6  ⋯  75.5  81.4
# 10 1968-01-01 2.4 49.0 6.6  1968 4.4  12.8  701.3 123.4 5.3  ⋯  80.3  84.6
# 11 1969-01-01 2.8 50.0 6.8  1969 4.8  13.6  722.5 125.9 5.0  ⋯  85.6  88.4
# 12 1970-01-01 2.7 49.4 7.0  1970 5.1  14.4  751.6 129.4 4.7  ⋯  92.0  92.5
# 13 1971-01-01 2.8 51.8 7.1  1971 5.1  14.8  779.2 130.0 4.6  ⋯  95.7  96.5
# 14 1972-01-01 3.1 55.4 7.4  1972 5.3  15.7  810.3 132.4 5.0  ⋯ 100.0 100.0
# 15 1973-01-01 3.4 59.3 7.9  1973 6.1  16.9  865.3 129.4 5.4  ⋯ 102.8 105.7
# 16 1974-01-01 3.7 58.7 7.8  1974 6.2  17.2  858.4 128.1 4.2  ⋯ 107.8 116.3
# 17 1975-01-01 3.6 60.9 7.4  1975 6.4  17.8  875.8 132.3 4.2  ⋯ 115.5 125.2
# 18 1976-01-01 4.0 63.8 7.5  1976 6.9  18.0  906.8 139.7 4.6  ⋯ 120.4 131.7
# 19 1977-01-01 4.3 67.5 7.8  1977 7.2  19.2  942.9 145.2 4.4  ⋯ 126.2 139.3
# 20 1978-01-01 4.7 73.6 8.1  1978 8.1  18.6  988.8 146.1 4.7  ⋯ 133.0 149.1
# 21 1979-01-01 5.1 76.7 8.4  1979 7.9  20.1 1015.5 149.3 4.7  ⋯ 141.0 162.5
# 22 1980-01-01 4.6 77.9 8.3  1980 8.1  21.5 1021.6 153.2 3.9  ⋯ 152.0 179.0
# 23 1981-01-01 4.1 82.6 8.3  1981 8.6  22.0 1049.3 153.0 3.6  ⋯ 164.2 194.5
# 24 1982-01-01 3.7 84.2 8.1  1982 8.6  22.4 1058.3 154.6 3.6  ⋯ 182.7 206.0
# 25 1983-01-01 3.8 88.5 8.1  1983 8.5  23.3 1095.4 161.2 4.0  ⋯ 218.4 213.6
#    PWAT  REC  TAB TELE TIME TOB  TPE    WAT
# 1   58.4  9.6 2.6  4.7  1   10.7  440.4 2.0
# 2   60.2 10.0 2.5  5.0  2   10.9  452.0 2.2
# 3   61.8 10.4 2.5  5.4  3   11.2  461.4 2.3
# 4   63.4 10.9 2.6  5.7  4   11.2  482.0 2.5
# 5   65.4 11.3 2.5  6.1  5   11.4  500.5 2.7
# 6   66.5 11.6 2.8  6.6  6   11.3  528.0 2.8
# 7   68.0 11.9 3.1  7.3  7   11.6  557.5 2.9
# 8   70.5 12.4 3.5  8.1  8   11.7  585.7 3.0
# 9   72.2 12.7 3.7  8.7  9   11.8  602.7 3.0
# 10  75.6 13.4 3.8  9.5 10   11.7  634.4 3.1
# 11  80.7 14.1 3.8 10.4 11   11.4  657.9 3.3
# 12  87.0 14.6 3.7 11.2 12   11.7  657.9 3.5
# 13  96.3 15.1 3.8 11.7 13   11.8  696.8 3.6
# 14 100.0 15.8 4.0 12.4 14   12.2  737.1 3.9
# 15 105.2 16.9 4.2 13.7 15   12.8  768.5 4.1
# 16 111.5 17.6 4.1 14.4 16   13.0  763.6 4.3
# 17 122.3 17.9 3.7 15.9 17   12.9  780.2 4.4
# 18 135.9 19.1 3.9 17.1 18   13.7  823.1 4.3
# 19 150.5 20.4 4.1 18.3 19   13.1  864.3 4.4
# 20 167.4 21.8 4.3 20.0 20   13.5  903.2 4.5
# 21 175.1 22.2 4.5 21.6 21   13.7  927.6 4.8
# 22 186.1 23.4 4.4 22.7 22   13.6  931.8 5.1
# 23 208.4 26.1 4.4 23.3 23   14.0  950.5 5.1
# 24 233.2 27.7 4.3 24.1 24   13.7  963.3 5.1
# 25 252.6 29.8 4.7 24.2 25   13.0 1009.2 5.1

# %%
mod1 <- lm(FOOD~PFOOD, data = data)

# %%
summary(mod1)
# Out:
# Call:
# lm(formula = FOOD ~ PFOOD, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.598  -5.651   0.269   3.987  10.929
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 88.65497    3.56434   24.87   <2e-16 ***
# PFOOD        0.32816    0.02721   12.06    2e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.096 on 23 degrees of freedom
# Multiple R-squared:  0.8634,	Adjusted R-squared:  0.8575
# F-statistic: 145.4 on 1 and 23 DF,  p-value: 2.004e-11

# %%
plot(mod1)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
sum(mod1$residuals[1:25])
# Out:
# [1] -5.995204e-15

# %%
a1<-mod1$residuals[1:24]
a2<-mod1$residuals[2:25]
plot(a1,a2)
# Out:
# plot without title

# %%
library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
ggtsdisplay(mod1$residuals)
# Out:
# plot without title

# %%
checkresiduals(mod1)
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 5
#
# data:  Residuals
# LM test = 17.954, df = 5, p-value = 0.003005
# plot without title

# %%
mod1 <- lm(HOUS~DPI, data = data)
ggtsdisplay(mod1$residuals)
# Out:
# plot without title

# %%
library(lmtest)
# Out:
# Загрузка требуемого пакета: zoo
#
#
# Присоединяю пакет: ‘zoo’
#
#
# Следующие объекты скрыты от ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
mod1 <- lm(COSM~DPI, data = data)
ggtsdisplay(mod1$residuals)
# Out:
# plot without title

# %%
summary(mod1)
# Out:
# Call:
# lm(formula = COSM ~ DPI, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.06656 -0.32737 -0.06412  0.58641  0.69526
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.3372820  0.4569091   0.738    0.468
# DPI         0.0079826  0.0005683  14.048 8.97e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5542 on 23 degrees of freedom
# Multiple R-squared:  0.8956,	Adjusted R-squared:  0.8911
# F-statistic: 197.3 on 1 and 23 DF,  p-value: 8.969e-13

# %%
dwtest(mod1)
# Out:
# 	Durbin-Watson test
#
# data:  mod1
# DW = 0.14512, p-value = 3.227e-15
# alternative hypothesis: true autocorrelation is greater than 0

# %%
dwtest(mod1, alternative = 'two.sided')
# Out:
# 	Durbin-Watson test
#
# data:  mod1
# DW = 0.14512, p-value = 6.454e-15
# alternative hypothesis: true autocorrelation is not 0

# %%
dwtest(mod1, alternative = 'less')
# Out:
# 	Durbin-Watson test
#
# data:  mod1
# DW = 0.14512, p-value = 1
# alternative hypothesis: true autocorrelation is less than 0

# %%
data1 <- read.csv('eaef30.csv')

# %%
mod2 <- lm(earn ~ asvabc, data = data1)
summary(mod2)
# Out:
# Call:
# lm(formula = earn ~ asvabc, data = data1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.411  -4.710  -1.557   2.648  66.857
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.35988    1.81857  -0.198    0.843
# asvabc       0.26874    0.03567   7.535 1.94e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.839 on 568 degrees of freedom
# Multiple R-squared:  0.09087,	Adjusted R-squared:  0.08927
# F-statistic: 56.78 on 1 and 568 DF,  p-value: 1.937e-13

# %%
dwtest(mod2, alternative = 'greater')

# %%
c1 <- ts(data['COSM'], frequency = 4, start=c(1990,1))
# h1 <- ts(data['HOUS'], frequency = 4, start=c(1990,1))
d1 <- ts(data['DPI'], frequency = 4, start=c(1990,1))

# %%
library('dynlm')

# %%
mod3 <- dynlm(c1~d1+L(c1))
summary(mod3)

# %%
dwtest(mod3, alternative = 'greater')

# %%
test <- dwtest(mod3, alternative = 'greater')

# %%
test$p.value
test$statistic

# %%
summary(mod3)$coefficients

# %%
# mod3$model
sel <- summary(mod3)$coefficients[3,2]

# %%
(1-0.5*test$statistic)*sqrt(24/(1-24*sel^2))

# %%
qnorm(0.95)# alpha = 5% for H_a: \rho>0  or  alpha = 10% H_a: \rho \neq 0

# %%
qnorm(0.975)

# %%
ggtsdisplay(mod3$residuals)

# %%
bgtest(mod3, order = 3)

# %%
bgtest(mod3, order = 5)

# %%
c1 <- ts(data['COSM'], frequency = 4, start=c(1990,1))
p1 <- ts(data['PCOSM'], frequency = 4, start=c(1990,1))
d1 <- ts(data['DPI'], frequency = 4, start=c(1990,1))

mod3 <- dynlm(c1~d1+p1+L(c1))
summary(mod3)

# %%
dwtest(mod3, alternative = 'greater')

# %%
library(ecm)
durbinH(mod3, "L(c1)")

# %%
test <- dwtest(mod3, alternative = 'greater')

# mod3$model
sel <- summary(mod3)$coefficients[4,2]

(1-0.5*test$statistic)*sqrt(24/(1-24*sel^2))

# %%
bgtest(mod3)

# %%
mod3 <- dynlm(c1~d1+L(c1))
summary(mod3)

dwtest(mod3, alternative = 'greater')

# %%
library(ecm)
ddd <- durbinH(mod3, "L(c1)")
ddd

# %%
res <- mod3$residuals

# %%
# mod4 <- dynlm(res~d1+p1+L(c1)+L(res))
mod4 <- dynlm(res~d1+L(c1)+L(res))
summary(mod4)

# %%
23*summary(mod4)$r.squared

# %%
qchisq(0.95,1)

# %%
bgtest(mod3)

# %% [markdown]
# One can notice that the results are slightly different from manual version as EViews adds zeros instead of missing data caused by lagging to prevent losing of degrees of freedom

# %%
# mod4 <- dynlm(res~d1+p1+L(c1)+L(res))
mod4 <- dynlm(res~d1+L(c1)+L(res)+L(res,2))
summary(mod4)

22*summary(mod4)$r.squared

qchisq(0.95,2)

# %%
bgtest(mod3, order = 2)

# %%
library(car)

# %%
linearHypothesis(mod4, c("L(res)=0", "L(res, 2)=0"))
